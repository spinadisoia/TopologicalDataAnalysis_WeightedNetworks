# %%
import numpy as np
from auxiliary_functions import *

np.random.seed(43)
random.seed(42)

# %% [markdown]
# # Toy network example

# %%
def create_toy_network():
    G = nx.Graph()
    
    for i in range(10):
        G.add_node(i)
    
    edges_to_add = [
        (0,1,0.98), (0,6,0.96), (2,3,0.95), (9,7,0.92),

        (1,5, 0.89), (6,5, 0.82), (8,4,0.87),

        (6,9,0.73), (3,8,0.77),

        (5,7,0.69), (2,8,0.63),

        (6,1,0.55),

        (7,8,0.45),

        (5,2,0.39), 

        (9,5, 0.27), (8,3,0.24)
    ]

    for u, v, weight in edges_to_add:
        if u not in G:
            G.add_node(u)
        if v not in G:
            G.add_node(v)
        G.add_edge(u, v, weight=weight)

    pos = nx.spring_layout(G, seed=43, k=0.3, iterations=100)
    return G, pos

G, fixed_pos = create_toy_network()
title = "Toy Network"

_=plot_network(G, title, fixed_pos)
# Out:
# c:\Users\sonia\OneDrive\Desktop\Tutto qui\UNI\UNITN\GEOMETRY\Project\Codes\auxiliary_functions.py:137: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# Example of a 3-clique and its corresponding clique complex

# %%
plot_clique(G, fixed_pos, clique_nodes=[0, 1, 6])
# Out:
# c:\Users\sonia\OneDrive\Desktop\Tutto qui\UNI\UNITN\GEOMETRY\Project\Codes\auxiliary_functions.py:233: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
plot_simplex(G, fixed_pos, clique_nodes=[0, 1, 6])
# Out:
# c:\Users\sonia\OneDrive\Desktop\Tutto qui\UNI\UNITN\GEOMETRY\Project\Codes\auxiliary_functions.py:266: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
plot_flag_complex(G, fixed_pos)
# Out:
# c:\Users\sonia\OneDrive\Desktop\Tutto qui\UNI\UNITN\GEOMETRY\Project\Codes\auxiliary_functions.py:301: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
plot_complex_with_holes(G, fixed_pos)

# %% [markdown]
# Filtration and persistence diagram

# %%
visualize_filtration(G, fixed_pos, title=title)

# %%
diagrams=get_persistence_diagram(G, title)

# %%
h1, h1_tilde = compute_hollowness(G, diagrams, homology_dim=1)

print("Hollowness h1:", h1)
print("Chain-length normalized hollowness ~h1:", h1_tilde)
# Out:
# Hollowness h1: 0.35999999999999993
# Chain-length normalized hollowness ~h1: 0.121

# %% [markdown]
# Null models

# %%
G_sh, pos_sh=randomize_weights(G, fixed_pos)
title_sh = "Toy Network with Randomized Weights"
analyze_persistence(G_sh, pos_sh, title_sh)
diagrams_sh = get_persistence_diagram(G_sh, title_sh, print_diagram=False)  
h1_sh, h1_tilde_sh = compute_hollowness(G_sh, diagrams_sh, homology_dim=1)
print("Hollowness h1:", h1_sh)
print("Chain-length normalized hollowness ~h1:", h1_tilde_sh)
# Out:
# Hollowness h1: 0.455
# Chain-length normalized hollowness ~h1: 0.1365

# %%
G_rnd, pos_rnd=randomize_edges_and_weights(G, fixed_pos)
title_rnd = "Toy Network with Randomized Edges"
analyze_persistence(G_rnd, pos_rnd, title_rnd)
diagrams_rnd = get_persistence_diagram(G_rnd, title_rnd, print_diagram=False)  
h1_rnd, h1_tilde_rnd = compute_hollowness(G_rnd, diagrams_rnd, homology_dim=1)
print("Hollowness h1:", h1_rnd)
print("Chain-length normalized hollowness ~h1:", h1_tilde_rnd)
# Out:
# Hollowness h1: 0.5900000000000001
# Chain-length normalized hollowness ~h1: 0.177

# %% [markdown]
# Compare hollowness

# %%
h1_values = [h1, h1_sh, h1_rnd]
h1_tilde_values = [h1_tilde, h1_tilde_sh, h1_tilde_rnd] 

for i in range(len(h1_values)):
    print(f"Network {i+1}: h1 = {h1_values[i]}, tilde_h1 = {h1_tilde_values[i]}")
# Out:
# Network 1: h1 = 0.35999999999999993, tilde_h1 = 0.121
# Network 2: h1 = 0.455, tilde_h1 = 0.1365
# Network 3: h1 = 0.5900000000000001, tilde_h1 = 0.177
